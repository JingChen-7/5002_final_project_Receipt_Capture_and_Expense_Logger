# %%
# !pip install paddleocr paddlepaddle
# Out:
# Requirement already satisfied: paddleocr in /opt/anaconda3/lib/python3.13/site-packages (3.2.0)
# Requirement already satisfied: paddlepaddle in /opt/anaconda3/lib/python3.13/site-packages (3.2.0)
# Requirement already satisfied: paddlex<3.3.0,>=3.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (3.2.1)
# Requirement already satisfied: PyYAML>=6 in /opt/anaconda3/lib/python3.13/site-packages (from paddleocr) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.12 in /opt/anaconda3/lib/python3.13/site-packages (from paddleocr) (4.12.2)
# Requirement already satisfied: aistudio_sdk>=0.3.5 in /opt/anaconda3/lib/python3.13/site-packages (from paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (0.3.8)
# Requirement already satisfied: chardet in /opt/anaconda3/lib/python3.13/site-packages (from paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (4.0.0)
# Requirement already satisfied: colorlog in /opt/anaconda3/lib/python3.13/site-packages (from paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (6.9.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.13/site-packages (from paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (3.17.0)
# Requirement already satisfied: huggingface_hub in /opt/anaconda3/lib/python3.13/site-packages (from paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (0.35.1)
# Requirement already satisfied: modelscope>=1.28.0 in /opt/anaconda3/lib/python3.13/site-packages (from paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (1.30.0)
# Requirement already satisfied: numpy>=1.24 in /opt/anaconda3/lib/python3.13/site-packages (from paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (2.1.3)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (24.2)
# Requirement already satisfied: pandas>=1.3 in /opt/anaconda3/lib/python3.13/site-packages (from paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (2.2.3)
# Requirement already satisfied: pillow in /opt/anaconda3/lib/python3.13/site-packages (from paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (11.1.0)
# Requirement already satisfied: prettytable in /opt/anaconda3/lib/python3.13/site-packages (from paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (3.16.0)
# Requirement already satisfied: py-cpuinfo in /opt/anaconda3/lib/python3.13/site-packages (from paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (9.0.0)
# Requirement already satisfied: pydantic>=2 in /opt/anaconda3/lib/python3.13/site-packages (from paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (2.10.3)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.13/site-packages (from paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (2.32.3)
# Requirement already satisfied: ruamel.yaml in /opt/anaconda3/lib/python3.13/site-packages (from paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (0.18.10)
# Requirement already satisfied: ujson in /opt/anaconda3/lib/python3.13/site-packages (from paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (5.10.0)
# Requirement already satisfied: imagesize in /opt/anaconda3/lib/python3.13/site-packages (from paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (1.4.1)
# Requirement already satisfied: opencv-contrib-python==4.10.0.84 in /opt/anaconda3/lib/python3.13/site-packages (from paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (4.10.0.84)
# Requirement already satisfied: pyclipper in /opt/anaconda3/lib/python3.13/site-packages (from paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (1.3.0.post6)
# Requirement already satisfied: pypdfium2>=4 in /opt/anaconda3/lib/python3.13/site-packages (from paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (4.30.0)
# Requirement already satisfied: shapely in /opt/anaconda3/lib/python3.13/site-packages (from paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (2.1.1)
# Requirement already satisfied: httpx in /opt/anaconda3/lib/python3.13/site-packages (from paddlepaddle) (0.28.1)
# Requirement already satisfied: protobuf>=3.20.2 in /opt/anaconda3/lib/python3.13/site-packages (from paddlepaddle) (5.29.3)
# Requirement already satisfied: opt_einsum==3.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from paddlepaddle) (3.3.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.13/site-packages (from paddlepaddle) (3.4.2)
# Requirement already satisfied: safetensors>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from paddlepaddle) (0.6.2)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.13/site-packages (from aistudio_sdk>=0.3.5->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (5.9.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.13/site-packages (from aistudio_sdk>=0.3.5->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (4.67.1)
# Requirement already satisfied: bce-python-sdk in /opt/anaconda3/lib/python3.13/site-packages (from aistudio_sdk>=0.3.5->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (0.9.46)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.13/site-packages (from aistudio_sdk>=0.3.5->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (8.1.8)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.13/site-packages (from modelscope>=1.28.0->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (72.1.0)
# Requirement already satisfied: urllib3>=1.26 in /opt/anaconda3/lib/python3.13/site-packages (from modelscope>=1.28.0->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=1.3->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=1.3->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=1.3->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic>=2->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic>=2->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (2.27.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.3->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (2025.8.3)
# Requirement already satisfied: pycryptodome>=3.8.0 in /opt/anaconda3/lib/python3.13/site-packages (from bce-python-sdk->aistudio_sdk>=0.3.5->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (3.23.0)
# Requirement already satisfied: future>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from bce-python-sdk->aistudio_sdk>=0.3.5->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (1.0.0)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.13/site-packages (from httpx->paddlepaddle) (4.7.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.13/site-packages (from httpx->paddlepaddle) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx->paddlepaddle) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.13/site-packages (from anyio->httpx->paddlepaddle) (1.3.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface_hub->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface_hub->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (1.1.10)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.13/site-packages (from prettytable->paddlex<3.3.0,>=3.2.0->paddlex[ocr-core]<3.3.0,>=3.2.0->paddleocr) (0.2.5)

# %%
import pandas as pd
from paddleocr import PaddleOCR

def parse_paddleocr_results(results):
    """
    通用解析 PaddleOCR 输出结果
    支持旧版 (box, (text, score)) 和 新版 dict 格式
    返回 pandas.DataFrame：['text', 'confidence', 'coords']
    """
    parsed_data = []

    # results[0] 是单张图的结果
    for line in results[0]:
        if isinstance(line, dict):  
            # 新版 dict 格式
            text = line.get('transcription', '')
            confidence = line.get('score', 0.0)
            coords = line.get('poly', [])
        elif isinstance(line, (list, tuple)) and len(line) == 2:
            # 旧版格式: (coords, (text, score))
            coords, info = line
            text, confidence = info
        else:
            continue  # 避免报错，跳过未知格式

        parsed_data.append({
            "text": text,
            "confidence": confidence,
            "coords": coords
        })

    return pd.DataFrame(parsed_data)


# ==== 示例使用 ====
ocr = PaddleOCR(use_textline_orientation=True)
results = ocr.predict("/Users/danchenluo/Desktop/1.jpg")
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/paddle/utils/cpp_extension/extension_utils.py:718: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/danchenluo/.paddlex/official_models/PP-LCNet_x1_0_doc_ori`.
# Creating model: ('UVDoc', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/danchenluo/.paddlex/official_models/UVDoc`.
# Creating model: ('PP-LCNet_x1_0_textline_ori', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/danchenluo/.paddlex/official_models/PP-LCNet_x1_0_textline_ori`.
# Creating model: ('PP-OCRv5_server_det', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/danchenluo/.paddlex/official_models/PP-OCRv5_server_det`.
# Creating model: ('PP-OCRv5_server_rec', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/Users/danchenluo/.paddlex/official_models/PP-OCRv5_server_rec`.

# %%
result = results[0]

# %%
for text, score, box in zip(result["rec_texts"], result["rec_scores"], result["rec_boxes"]):
    print(f"Text: {text}, Confidence: {score:.2f}, Box: {box}")
# Out:
# Text: tan woon yann, Confidence: 0.99, Box: [53 ... 33]
# Text: BOOKTAK(TAMAN DAYA)SDNBHD, Confidence: 0.95, Box: [49 ... 93]
# Text: 789417-W, Confidence: 0.99, Box: [200 ... 120]
# Text: NO.5:55,57 &59,JALAN SAGU18, Confidence: 0.91, Box: [ 93 ... 152]
# Text: TAMAN DAYA,, Confidence: 0.95, Box: [182 ... 175]
# Text: 81100 JOHOR BAHRU,, Confidence: 0.91, Box: [148 ... 201]
# Text: JOHOR., Confidence: 0.98, Box: [210 ... 221]
# Text: Document No:TD01167104, Confidence: 0.95, Box: [ 27 ... 356]
# Text: Date:, Confidence: 0.93, Box: [ 23 ... 392]
# Text: 25/12/20188:13:39PM, Confidence: 0.98, Box: [150 ... 393]
# Text: Cashier:, Confidence: 0.96, Box: [ 25 ... 420]
# Text: MANIS, Confidence: 1.00, Box: [152 ... 415]
# Text: Member:, Confidence: 0.95, Box: [ 24 ... 447]
# Text: CASH BILL, Confidence: 0.96, Box: [182 ... 486]
# Text: CODE/DESC, Confidence: 1.00, Box: [  1 ... 538]
# Text: PRICE, Confidence: 0.98, Box: [190 ... 533]
# Text: Disc, Confidence: 0.97, Box: [275 ... 530]
# Text: AMOUN, Confidence: 0.95, Box: [382 ... 530]
# Text: QTY, Confidence: 0.99, Box: [ 47 ... 567]
# Text: RM, Confidence: 0.89, Box: [217 ... 556]
# Text: RM, Confidence: 0.98, Box: [431 ... 555]
# Text: 9556939040118, Confidence: 0.98, Box: [  4 ... 599]
# Text: KF MODELLINGCLAY KIDDYFISH, Confidence: 0.90, Box: [150 ... 599]
# Text: 1PC, Confidence: 0.99, Box: [ 56 ... 630]
# Text: *, Confidence: 0.82, Box: [127 ... 623]
# Text: 9.000, Confidence: 1.00, Box: [196 ... 626]
# Text: 0.00, Confidence: 0.99, Box: [275 ... 626]
# Text: 9.00, Confidence: 1.00, Box: [421 ... 624]
# Text: Total:, Confidence: 0.97, Box: [240 ... 674]
# Text: 9.00, Confidence: 0.99, Box: [419 ... 669]
# Text: Rour ding Adjustment:, Confidence: 0.93, Box: [105 ... 708]
# Text: 0.00, Confidence: 0.99, Box: [422 ... 700]
# Text: Round d Total(RM):, Confidence: 0.91, Box: [ 71 ... 746]
# Text: 9.00, Confidence: 0.99, Box: [412 ... 736]
# Text: Cash, Confidence: 1.00, Box: [199 ... 783]
# Text: 10.00, Confidence: 0.95, Box: [422 ... 781]
# Text: CHANGE, Confidence: 1.00, Box: [199 ... 808]
# Text: GOODS SOLD ARE NOT RETURNABLEOR, Confidence: 0.91, Box: [ 82 ... 893]
# Text: EXCHANGEABLE, Confidence: 1.00, Box: [186 ... 905]
# Text: 物出门想不退还或更换, Confidence: 0.86, Box: [134 ... 930]
# Text: 如有下便，敬请座谅。谢！, Confidence: 0.73, Box: [129 ... 951]
# Text: THANK YOU, Confidence: 0.97, Box: [200 ... 988]
# Text: PLEASECO'EAGAIN!, Confidence: 0.93, Box: [ 157 ... 1012]
